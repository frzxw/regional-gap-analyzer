# %%
import pandas as pd

# %%
df = pd.read_csv('../../raw/tingkat-pengangguran-terbuka/2024.csv', skiprows=3)
df
# Out:
#               Unnamed: 0  Februari  Agustus Tahunan
# 0                   ACEH      5.56     5.75       -
# 1         SUMATERA UTARA      5.10     5.60       -
# 2         SUMATERA BARAT      5.79     5.75       -
# 3                   RIAU      3.85     3.70       -
# 4                  JAMBI      4.45     4.48       -
# 5       SUMATERA SELATAN      3.97     3.86       -
# 6               BENGKULU      3.17     3.11       -
# 7                LAMPUNG      4.12     4.19       -
# 8   KEP. BANGKA BELITUNG      3.85     4.63       -
# 9              KEP. RIAU      6.94     6.39       -
# 10           DKI JAKARTA      6.03     6.21       -
# 11            JAWA BARAT      6.91     6.75       -
# 12           JAWA TENGAH      4.39     4.78       -
# 13         DI YOGYAKARTA      3.24     3.48       -
# 14            JAWA TIMUR      3.74     4.19       -
# 15                BANTEN      7.02     6.68       -
# 16                  BALI      1.87     1.79       -
# ...
